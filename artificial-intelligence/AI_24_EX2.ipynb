# %% [markdown]
# ##### ❗Προσοχή: Συμπληρώστε τα ονόματα των μελών της ομάδας σας
#
#      Ονοματεπώνυμο 1ου μέλους: Φίλιππος Μαρντιροσιάν
#              email 1ου μέλους: el20034@mail.ntua.gr
#              philipmardir@gmail.com
#
#      Ονοματεπώνυμο 2ου μέλους: Γεώργιος Θεοδοσίου
#              email 2ου μέλους: el20109@mail.ntua.gr
#              georgetheo19@gmail.com

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Ενότητα 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="MyDrive/AI_24_ex2/" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
path = '/content/drive/MyDrive/AI_24_ex2/'
# Διάβασμα του αρχείου 'movie_metadata.csv'
data = pd.read_csv(path + "movies_metadata.csv")
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):

  movie_title = clean_text(getattr(row, 'movie_title'))

  for genre in clean_text(getattr(row, 'genres')).split("|"):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")

  for plot_keywords in clean_text(getattr(row, 'plot_keywords')).split("|"):
    literals.append("plot_keywords('"+ movie_title +"','"+ plot_keywords +"')")

  for productionCompany in list(eval(getattr(row, 'production_companies'))):
    pcname = productionCompany["name"].replace("'", "")
    literals.append(f"production_company('{movie_title}','{pcname}')")

  for productionCountry in list(eval(getattr(row, 'production_countries'))):
    pcname = productionCountry["name"].replace("'", "")
    literals.append(f"production_country('{movie_title}','{pcname}')")


  literals.append("language('"+ movie_title +"','"+ clean_text(getattr(row, 'language')) +"')")

  literals.append("overview('"+ movie_title +"','"+ clean_text(getattr(row, 'overview')) +"')")

  literals.append("popularity('"+ movie_title +"','"+ str(getattr(row, 'popularity')) +"')")

  literals.append("tagline('"+ movie_title +"','"+ clean_text(getattr(row, 'tagline')) +"')")

  literals.append("vote_average('"+ movie_title +"','"+ str(getattr(row, 'vote_average')) +"')")

  literals.append("decade('"+ movie_title +"','"+ str(getattr(row, 'vote_average') - getattr(row, 'vote_average')%10) +"')")

  literals.append("num_voted_users('"+ movie_title +"','"+ str(getattr(row, 'num_voted_users')) +"')")

  literals.append("title_year('"+ movie_title +"','"+ str(getattr(row, 'title_year')) +"')")

  literals.append("country('"+ movie_title +"','"+ clean_text(getattr(row, 'country')) +"')")

  literals.append("director_name('"+ movie_title +"','"+ clean_text(getattr(row, 'director_name')) +"')")

  literals.append("actor_1_name('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_1_name')) +"')")

  literals.append("actor_2_name('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_2_name')) +"')")

  literals.append("actor_3_name('"+ movie_title +"','"+ clean_text(getattr(row, 'actor_3_name')) +"')")

#Η Prolog θέλει τα κατηγορήματά της με την σειρά
literals.sort()
for literal in literals:
  prolog.assertz(literal)
  #print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
prolog.consult(path + "db.pl")

# %%
q = prolog.query("same_genre_1('Interstellar', Y)")
s = set()
for soln in q:
  s.add(soln['Y'])
print(s)
q.close()
# Out:
# {'The Motel', 'Aimee & Jaguar', 'The Glass House', 'Solaris', 'A Prairie Home Companion', 'The Horseman on the Roof', 'Stranger Than Fiction', 'The Remains of the Day', 'xXx: State of the Union', 'High Crimes', 'Goldfinger', 'Jab Tak Hai Jaan', 'Class of 1984', 'The Lunchbox', 'October Baby', 'Sunshine Cleaning', 'Albert Nobbs', 'Sherlock Holmes: A Game of Shadows', 'In Her Line of Fire', '200 Cigarettes', 'Joy Ride', 'The Adventures of Pluto Nash', 'Deadpool', 'Don Jon', 'Dead Man Walking', 'Copycat', 'The Last Song', 'The Wizard of Oz', 'CJ7', 'Rubber', 'GoodFellas', 'The Fault in Our Stars', 'Tin Cup', 'Four Weddings and a Funeral', 'Home', 'Digimon: The Movie', 'Rotor DR1', '9', 'Dragon Nest: Warriors Dawn', 'Deep Rising', 'Licence to Kill', 'Dazed and Confused', 'Surrogates', 'Ali', 'Motherhood', 'Underworld: Rise of the Lycans', 'LOL', 'The Art of Getting By', 'The Hudsucker Proxy', 'They Live', 'Love & Basketball', 'Basic', 'Shortbus', 'Son of God', 'Flatliners', 'The Lives of Others', 'Beyond the Valley of the Dolls', 'The Great Gatsby', 'Beneath the Planet of the Apes', 'Ordinary People', 'Ordet', 'People I Know', 'Lady in the Water', 'Yours, Mine and Ours', 'Summer Storm', 'The Crocodile Hunter: Collision Course', 'Broken Vessels', 'Under the Same Moon', 'Cellular', 'Fantastic 4: Rise of the Silver Surfer', 'Sugar Hill', 'The Last House on the Left', 'The Artist', 'Wild Grass', 'Ladder 49', 'Shouldve Been Romeo', 'Imaginary Heroes', 'Big Daddy', 'Butterfly', 'The Country Doctor', 'Fort McCoy', 'High School Musical 2', 'Battle for the Planet of the Apes', 'The Boys from Brazil', 'Hostage', 'Coriolanus', 'L.I.E.', 'George and the Dragon', 'Witless Protection', 'The Rookie', 'The SpongeBob Movie: Sponge Out of Water', 'Whats Eating Gilbert Grape', 'Shadowlands', 'The Second Mother', 'Bless the Child', 'Forgetting Sarah Marshall', 'The Polar Express', 'The Godfather', 'The Wolfman', 'Angel Eyes', 'Lucky You', 'Six Days Seven Nights', 'Runner Runner', 'My Fair Lady', 'Courageous', '8 Mile', 'Antiviral', 'Rango', 'Varsity Blues', 'Poolhall Junkies', 'Lockout', 'Shanghai Noon', 'Alvin and the Chipmunks: The Road Chip', 'Lovely & Amazing', '#Horror', 'Brother', 'Hamlet', 'Ray', 'Wuthering Heights', 'Extraordinary Measures', 'The Express', 'A Man for All Seasons', 'Clay Pigeons', 'Sunshine', 'By the Sea', 'Spectre', 'Robot & Frank', 'Conquest of the Planet of the Apes', 'Deuces Wild', 'Somethings Gotta Give', 'Proud', 'Rivers Edge', 'August', 'The Egyptian', 'The Dark Knight Rises', 'Chappie', 'The Shawshank Redemption', 'The Perez Family', 'Star Trek Into Darkness', 'American Splendor', 'Dantes Peak', 'Dracula Untold', 'The Charge of the Light Brigade', '3 Ninjas Kick Back', 'Monsters vs Aliens', 'Anne of Green Gables', 'City By The Sea', 'Nine', 'Fateless', 'Double Impact', 'The Legend of Hells Gate: An American Conspiracy', 'Hulk', 'Beyond Borders', '42', 'The Tale of Despereaux', 'Cars', 'Adore', 'Kung Fu Panda', 'Instinct', 'When the Lights Went Out', 'Blue Jasmine', 'Winnie Mandela', 'In Dreams', 'Run Lola Run', 'Get on the Bus', 'Radio Days', 'All Is Bright', 'You Can Count on Me', 'The Wood', 'Seeking a Friend for the End of the World', 'Three Kings', 'Mrs. Doubtfire', 'Harvard Man', 'Brave', 'Everything Put Together', 'The Damned United', 'Rapa Nui', 'Gridiron Gang', 'Forsaken', 'Flubber', 'The Martian', 'Room', 'Donovans Reef', 'Any Given Sunday', 'Flightplan', 'Deep Blue Sea', 'The Weather Man', 'Pans Labyrinth', 'The Importance of Being Earnest', 'The Virgin Suicides', 'Youth in Revolt', 'Random Hearts', 'Velvet Goldmine', 'Brotherly Love', 'Captain America: The First Avenger', 'War, Inc.', 'Ondine', 'White Squall', 'Tracker', 'Synecdoche, New York', 'Chain of Command', 'The Expendables', 'Harriet the Spy', 'Monster', 'The New World', 'Mondays in the Sun', 'Thunderbirds', 'Alone With Her', 'Vantage Point', 'Just Looking', 'Emma', 'Nothing to Lose', 'Dick Tracy', 'Conspiracy Theory', 'Full Frontal', 'The Chronicles ...

# %%
q1 = prolog.query("same_director('Interstellar', Y)")
s = set()
for soln in q1:
  s.add(soln['Y'])
print(s)
q1.close()
# Out:
# {'The Dark Knight', 'The Prestige', 'Memento', 'Inception', 'The Dark Knight Rises', 'Batman Begins', 'Insomnia'}

# %%
q = prolog.query("same_actor_3('Interstellar', Y)")
s = set();
for soln in q:
  s.add(soln["Y"])

q.close()
print(s)
# Out:
# set()

# %%
q = prolog.query("same_language('Interstellar', Y)")
s = set();
for soln in q:
  s.add(soln["Y"])

q.close()
print(s)
# Out:
# {'The Goods: Live Hard, Sell Hard', 'Super Troopers', 'The Motel', 'A Prairie Home Companion', 'Extreme Movie', 'Stone Cold', 'Stranger Than Fiction', 'The Remains of the Day', 'xXx: State of the Union', 'Graduation Day', 'High Crimes', 'The Lunchbox', 'Class of 1984', 'The Master of Disguise', 'October Baby', 'Sunshine Cleaning', 'Albert Nobbs', 'Sherlock Holmes: A Game of Shadows', 'Cats & Dogs', 'In Her Line of Fire', 'Insidious: Chapter 2', '200 Cigarettes', 'Joy Ride', 'The Adventures of Pluto Nash', 'Deadpool', 'Unfinished Business', 'Unstoppable', 'Don Jon', 'Dead Man Walking', 'Copycat', 'That Awkward Moment', 'The Last Song', 'The Wizard of Oz', 'Rubber', 'Final Destination 5', 'The Fault in Our Stars', 'Tin Cup', 'Four Weddings and a Funeral', 'Home', 'Jason Goes to Hell: The Final Friday', '9', 'Licence to Kill', 'Dazed and Confused', 'Shanghai Calling', 'Surrogates', 'Ali', 'Dolphins and Whales: Tribes of the Ocean', 'Motherhood', 'The Tigger Movie', 'LOL', 'Underworld: Rise of the Lycans', 'Sisters in Law', 'My Big Fat Independent Movie', 'The Art of Getting By', 'The Hudsucker Proxy', 'They Live', 'Love & Basketball', 'Basic', 'Shortbus', 'Son of God', 'Flatliners', 'Beyond the Valley of the Dolls', 'The Great Gatsby', 'Beneath the Planet of the Apes', 'Ordinary People', 'Winged Migration', 'People I Know', 'Failure to Launch', 'Lady in the Water', '102 Dalmatians', 'Smiling Fish & Goat On Fire', 'Yours, Mine and Ours', 'Breakin All the Rules', 'The Crocodile Hunter: Collision Course', 'Under the Same Moon', 'The R.M.', 'Jaws 2', 'Cellular', 'Fantastic 4: Rise of the Silver Surfer', 'Sugar Hill', 'The Last House on the Left', 'April Fools Day', 'Ladder 49', 'Shouldve Been Romeo', 'Imaginary Heroes', 'Big Daddy', 'A Low Down Dirty Shame', 'High School Musical 2', 'Pitch Perfect', 'Battle for the Planet of the Apes', 'The Boys from Brazil', 'Everyone Says I Love You', 'A League of Their Own', 'Bon Cop Bad Cop', 'Hostage', 'Saw', 'Sin City', 'Coriolanus', 'L.I.E.', 'Big Fat Liar', 'The Hammer', 'George and the Dragon', 'Witless Protection', 'The Rookie', 'The SpongeBob Movie: Sponge Out of Water', 'Whats Eating Gilbert Grape', 'Shadowlands', 'Scoop', 'Drop Dead Gorgeous', 'Bless the Child', 'Forgetting Sarah Marshall', 'The Godfather', 'The Polar Express', 'The Wolfman', 'Pretty Woman', 'Angel Eyes', 'Lucky You', 'Six Days Seven Nights', 'Runner Runner', 'My Fair Lady', 'Courageous', '8 Mile', 'Hairspray', 'Antiviral', 'Were the Millers', 'Yoga Hosers', 'Rango', 'Varsity Blues', 'Connie and Carla', 'Lockout', 'Bruce Almighty', 'Poolhall Junkies', 'Shanghai Noon', 'Alvin and the Chipmunks: The Road Chip', 'Lovely & Amazing', '#Horror', 'Brother', 'Dinosaur', 'Hamlet', 'Novocaine', 'Madagascar 3: Europes Most Wanted', 'Ray', 'The Nutcracker', 'Wuthering Heights', 'Extraordinary Measures', 'Antibirth', 'The Express', 'A Man for All Seasons', 'Clay Pigeons', 'Sunshine', 'Robot & Frank', 'Ayurveda: Art of Being', 'Raymond Did It', 'The Work and The Story', 'Sea Rex 3D: Journey to a Prehistoric World', 'Obvious Child', 'Playing for Keeps', 'Conquest of the Planet of the Apes', 'Grudge Match', 'Home Alone', 'Deuces Wild', 'Just Married', 'Rivers Edge', 'The Dark Knight Rises', 'Hostel: Part II', 'Chappie', 'Small Time Crooks', 'The Blues Brothers', 'The Perez Family', 'The Shawshank Redemption', '13 Going on 30', 'Star Trek Into Darkness', 'American Splendor', 'Stay Alive', 'Dantes Peak', 'Ride Along 2', 'Fat, Sick & Nearly Dead', 'Dracula Untold', 'Vacation', 'Domino', 'The Charge of the Light Brigade', '3 Ninjas Kick Back', 'Anne of Green Gables', 'Monsters vs Aliens', 'City By The Sea', 'Unknown', 'Half Past Dead', 'Fateless', 'Nine', 'Double Impact', 'The Legend of Hells Gate: An American Conspiracy', '2016: Obamas America', 'Hulk', 'Analyze That', 'Beyond Borders', 'Insomnia', 'Scream 3', 'Adore', 'Cars', 'The Tale of Despereaux', 'Kung Fu Panda', 'Instinct', 'Serendipity', 'When the Lights Went Out', 'Blue Jasmine',  ...

# %%
q = prolog.query("not_colored(X)")
s = set();
for soln in q:
  s.add(soln['X'])

q.close()
print(s)
# Out:
# {'Frankenweenie', 'Frances Ha', 'The Phantom of the Opera', 'Creative Control', 'The Giver', 'Renaissance'}

# %%
q = prolog.query("same_decade('Avatar', Y)")
s = set();
for soln in q:
  s.add(soln["Y"])

q.close()
print(s)
# Out:
# {'The Goods: Live Hard, Sell Hard', 'Super Troopers', 'The Motel', 'Aimee & Jaguar', 'The Glass House', 'Solaris', 'A Prairie Home Companion', 'Extreme Movie', 'Rise of the Entrepreneur: The Search for a Better Way', 'The Horseman on the Roof', 'Stone Cold', 'Stranger Than Fiction', 'The Remains of the Day', 'xXx: State of the Union', 'Graduation Day', 'High Crimes', 'Goldfinger', 'Jab Tak Hai Jaan', 'Class of 1984', 'The Lunchbox', 'Dragon Hunters', 'The Master of Disguise', 'October Baby', 'Sunshine Cleaning', 'Albert Nobbs', 'Sherlock Holmes: A Game of Shadows', 'Cats & Dogs', 'In Her Line of Fire', 'Insidious: Chapter 2', '200 Cigarettes', 'Joy Ride', 'The Adventures of Pluto Nash', 'Deadpool', 'Unfinished Business', 'Unstoppable', 'Don Jon', 'Dead Man Walking', 'Copycat', 'That Awkward Moment', 'The Last Song', 'CJ7', 'Rubber', 'The Princess and the Frog', 'The Wizard of Oz', 'Final Destination 5', 'GoodFellas', 'The Fault in Our Stars', 'Tin Cup', 'Four Weddings and a Funeral', 'Home', 'Digimon: The Movie', 'Jason Goes to Hell: The Final Friday', 'Rotor DR1', '9', 'Dragon Nest: Warriors Dawn', 'Dazed and Confused', 'Deep Rising', 'Licence to Kill', 'Shanghai Calling', 'Surrogates', 'Ali', 'Dolphins and Whales: Tribes of the Ocean', 'Motherhood', 'The Tigger Movie', 'LOL', 'Rush Hour 2', 'Sisters in Law', 'My Big Fat Independent Movie', 'The Art of Getting By', 'The Hudsucker Proxy', 'They Live', 'Underworld: Rise of the Lycans', 'Love & Basketball', 'Basic', 'Shortbus', 'Son of God', 'Flatliners', 'The Lives of Others', 'Beyond the Valley of the Dolls', 'The Great Gatsby', 'Beneath the Planet of the Apes', 'Ordinary People', 'Ordet', 'People I Know', 'Failure to Launch', 'Lady in the Water', '102 Dalmatians', 'Smiling Fish & Goat On Fire', 'Winged Migration', 'Summer Storm', 'Breakin All the Rules', '51 Birch Street', 'Broken Vessels', 'The Crocodile Hunter: Collision Course', 'Under the Same Moon', 'The R.M.', 'Evil Words', 'Jaws 2', 'Cellular', 'Fantastic 4: Rise of the Silver Surfer', 'Sugar Hill', 'The Last House on the Left', 'The Artist', 'Wild Grass', 'April Fools Day', 'Ladder 49', 'Shouldve Been Romeo', 'Imaginary Heroes', 'Big Daddy', 'Butterfly', 'A Low Down Dirty Shame', 'The Country Doctor', 'Fort McCoy', 'High School Musical 2', 'Pitch Perfect', 'Battle for the Planet of the Apes', 'The Boys from Brazil', 'Everyone Says I Love You', 'A League of Their Own', 'Bon Cop Bad Cop', 'Hostage', 'Saw', 'Sin City', 'Coriolanus', 'L.I.E.', 'Big Fat Liar', 'The Hammer', 'George and the Dragon', 'Witless Protection', 'The Rookie', 'The SpongeBob Movie: Sponge Out of Water', 'Whats Eating Gilbert Grape', 'Shadowlands', 'Scoop', 'Drop Dead Gorgeous', 'The Second Mother', 'Bless the Child', 'Forgetting Sarah Marshall', 'The Godfather', 'The Polar Express', 'The Wolfman', 'Pretty Woman', 'Angel Eyes', 'Lucky You', 'Six Days Seven Nights', 'Runner Runner', 'My Fair Lady', 'Courageous', '8 Mile', 'Doc Hollidays Revenge', 'Antiviral', 'Hairspray', 'Were the Millers', 'Rango', 'Yoga Hosers', 'Varsity Blues', 'Connie and Carla', 'Lockout', 'Bruce Almighty', 'Poolhall Junkies', 'Shanghai Noon', 'Alvin and the Chipmunks: The Road Chip', 'Lovely & Amazing', '#Horror', 'Brother', 'Dinosaur', 'Hamlet', 'Novocaine', 'Madagascar 3: Europes Most Wanted', 'Ray', 'The Nutcracker', 'Wuthering Heights', 'Extraordinary Measures', 'Antibirth', 'Boomerang', 'A Man for All Seasons', 'Clay Pigeons', 'Sunshine', 'The Express', 'By the Sea', 'Robot & Frank', 'Spectre', 'Ayurveda: Art of Being', 'Raymond Did It', 'The Work and The Story', 'Sea Rex 3D: Journey to a Prehistoric World', 'Obvious Child', 'Playing for Keeps', 'Conquest of the Planet of the Apes', 'Grudge Match', 'Home Alone', 'Deuces Wild', 'Just Married', 'The Vatican Exorcisms', 'Tarnation', 'Somethings Gotta Give', 'Proud', 'Rivers Edge', 'August', 'The Egyptian', 'The Dark Knight Rises', 'Hostel: Part II', 'Chappie', 'Small Time Crooks', 'The Blues Brothers', 'The Perez Family', 'Th ...

# %%
# prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
def simple_recommender(movie):
  s = set()
  for i in range (1,6):
    q = prolog.query("find_sim_"+ str(i) +"('" + movie +"',M)")
    for soln in q:
      m = soln['M']
      if m not in s:
        s.add(m)
    q.close()
  answers = s
  return answers

# %%
list(simple_recommender('Inception'))[::-1]
# Out:
# ['Battleship',
#  'Teenage Mutant Ninja Turtles',
#  'Texas Chainsaw 3D',
#  'Friday the 13th: A New Beginning',
#  'How to Train Your Dragon',
#  'Battle: Los Angeles',
#  'Godzilla 2000',
#  'Dredd',
#  'Scarface',
#  'Splice',
#  'The Amazing Spider-Man',
#  'The Fountain',
#  'Fugly',
#  'The Sisterhood of the Traveling Pants 2',
#  'The In Crowd',
#  'True Grit',
#  'The Lost Medallion: The Adventures of Billy Stone',
#  'The Dead Undead',
#  'The Beastmaster',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Heist',
#  'All Superheroes Must Die',
#  'My Bloody Valentine',
#  '2:13',
#  'Extreme Ops',
#  'Good Kill',
#  'Arn: The Knight Templar',
#  'Star Wars: Episode I - The Phantom Menace',
#  'Sublime',
#  'The Equalizer',
#  'Knight and Day',
#  'Lords of London',
#  'Force 10 from Navarone',
#  'Mulholland Drive',
#  'Before I Go to Sleep',
#  'Out of the Furnace',
#  'Walking With Dinosaurs',
#  'D.E.B.S.',
#  'Face/Off',
#  'Freddys Dead: The Final Nightmare',
#  'Listening',
#  '47 Ronin',
#  'Two Evil Eyes',
#  'Eraserhead',
#  'The Bone Collector',
#  'The Legend of Tarzan',
#  'Supercapitalist',
#  'King Kong',
#  'Event Horizon',
#  'Fifty Shades of Grey',
#  'The Watcher',
#  'Point Break',
#  'The Other Guys',
#  'The Wolverine',
#  'Captain America: The Winter Soldier',
#  'The Cave',
#  'Halloween: Resurrection',
#  'Outbreak',
#  'The Limey',
#  'Fear and Loathing in Las Vegas',
#  'Scott Pilgrim vs. the World',
#  'BloodRayne',
#  'Kiss of Death',
#  'The Thirteenth Floor',
#  'Ink',
#  'Suicide Squad',
#  'Ishtar',
#  'Mad Max 2: The Road Warrior',
#  'Enter Nowhere',
#  'Phantasm II',
#  'Species',
#  'The Final Destination',
#  'Superhero Movie',
#  'Beastmaster 2: Through the Portal of Time',
#  'Trade Of Innocents',
#  'Avatar',
#  'The Crazies',
#  'Escape from the Planet of the Apes',
#  'Shanghai Knights',
#  'Dressed to Kill',
#  'Northfork',
#  'City of Ember',
#  'Harold & Kumar Go to White Castle',
#  'Up',
#  'Shrek',
#  'Jupiter Ascending',
#  'The Impossible',
#  'Rat Race',
#  'Prometheus',
#  'A Man Apart',
#  'The Glimmer Man',
#  'Femme Fatale',
#  'Re-Kill',
#  'Timeline',
#  'C.H.U.D.',
#  'Inspector Gadget',
#  'Pixels',
#  'Conan the Barbarian',
#  'Harsh Times',
#  'Drive',
#  'The First Great Train Robbery',
#  'Thor',
#  'Prince of Persia: The Sands of Time',
#  'Gosford Park',
#  'Lakeview Terrace',
#  'The Wiz',
#  'Cop Land',
#  'Warcraft',
#  'Paycheck',
#  '2001: A Space Odyssey',
#  'Ghost Rider: Spirit of Vengeance',
#  'Curse of the Golden Flower',
#  'Safe',
#  'Double Take',
#  'Body Double',
#  'The Legend of the Lone Ranger',
#  'Sky High',
#  'The Vatican Tapes',
#  'Steel',
#  'Blue Ruin',
#  'Jaws',
#  'Exodus: Gods and Kings',
#  'Apollo 18',
#  'Young Sherlock Holmes',
#  'The Matador',
#  'Once Upon a Time in Mexico',
#  'Layer Cake',
#  'Lucky Break',
#  'The Abyss',
#  'Sea of Love',
#  'Desperado',
#  'Phenomenon',
#  'Platoon',
#  'Flyboys',
#  'Gothika',
#  'Planet 51',
#  'Fools Gold',
#  'The Mothman Prophecies',
#  'Highlander',
#  'Dirty Pretty Things',
#  'Def-Con 4',
#  'Vessel',
#  'A.I. Artificial Intelligence',
#  'Chloe',
#  'Side Effects',
#  'The Timber',
#  'Excessive Force',
#  'Epic',
#  'The Lost Skeleton of Cadavra',
#  'Ransom',
#  'Rob Roy',
#  'Baahubali: The Beginning',
#  'Cape Fear',
#  'The League of Extraordinary Gentlemen',
#  'Beverly Hills Chihuahua',
#  'Sphere',
#  'American Hero',
#  'Smillas Sense of Snow',
#  'Premium Rush',
#  'Bolt',
#  'Undercover Brother',
#  'Star Trek: First Contact',
#  'Bad Boys II',
#  'Mirrors',
#  'Muppets from Space',
#  'The Spiderwick Chronicles',
#  'Warriors of Virtue',
#  'Kill Bill: Vol. 2',
#  'The Little Prince',
#  'The Hunger Games: Mockingjay - Part 2',
#  'Mission: Impossible - Rogue Nation',
#  'The Purge: Anarchy',
#  'Star Wars',
#  'Unbreakable',
#  'FearDotCom',
#  'Blow Out',
#  'The Lincoln Lawyer',
#  'The Rock',
#  'Munich',
#  'This Is the End',
#  'Adulterers',
#  'White Fang',
#  'Diary of the Dead',
#  'The Edge',
#  'Man of Steel',
#  'Non-Stop',
#  'The Marine 4: Moving Target',
#  'D-Tox',
#  'Terminator 2: Judgment Day',
#  'Eragon',
#  'Ripleys Game',
#  'Scooby-Doo 2: Monsters Unleashed',
#  'Urban Legend',
#  'Quest for Fire',
#  'U.F.O.',
#  'We Own the Night',
#  'X-Men Origins: Wolverine',
#  'The Ice Pirates',
#  'Snake Eyes',
#  '28 Weeks Later',
#  'Womb',
#  'Clear and Present Danger',
#  'September Dawn',
#  'The Fugitive',
#  'Reign of Fire',
#  'Lucky Numbers',
#  'Machete',
#  'Dead Man Down',
#  'Max Payne',
#  'Sorority Row',
#  'The Great Raid',
#  'Night at the Museum: Secret of the Tomb',
#  'Dragonball Evolution',
#  'The Brain That Wouldnt Die',
#  'Exorcist: The Beginning',
#  'The Cold Light of Day',
#  'Highway',
#  'Hells Angels',
#  'Kansas City',
#  'Thir13en Ghosts',
#  'Survival of the Dead',
#  'Risen',
#  'Elysium',
#  'Day of the Dead',
#  'Final Destination 2',
#  'Supercross',
#  'Madison',
#  'The Shallows',
#  'This Means War',
#  'The Death and Life of Bobby Z',
#  'Armageddon',
#  'Touching the Void',
#  'I Origins',
#  'Paul',
#  'No Mans Land: The Rise of Reeker',
#  'Chicago',
#  'The Curse of the Jade Scorpion',
#  'The 6th Day',
#  'A View to a Kill',
#  'Fetching Cody',
#  'The Devils Tomb',
#  'Unleashed',
#  'Shadow Conspiracy',
#  'Open Season',
#  'Babys Day Out',
#  'Speed 2: Cruise Control',
#  'Blade Runner',
#  'Men in Black',
#  'Down to Earth',
#  'Book of Shadows: Blair Witch 2',
#  'Derailed',
#  'Titanic',
#  'The Astronauts Wife',
#  'The Swindle',
#  'Romeo Is Bleeding',
#  'Malone',
#  'The Man from Earth',
#  'The Contender',
#  'Unsullied',
#  'The Transporter',
#  'Black Christmas',
#  'The Last Days on Mars',
#  'Wyatt Earp',
#  'The Four Feathers',
#  'Green Room',
#  'Scooby-Doo',
#  'Born Of War',
#  'Nerve',
#  'We Have Your Husband',
#  'Panic Room',
#  'Are We There Yet?',
#  'Final Fantasy: The Spirits Within',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'I Spy',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'Jurassic World',
#  'The Frozen',
#  'Laws of Attraction',
#  'Escape from Planet Earth',
#  'The Order',
#  'Man on Wire',
#  'The Hitchhikers Guide to the Galaxy',
#  'Lara Croft: Tomb Raider',
#  'Goosebumps',
#  'Sexy Beast',
#  'All the Boys Love Mandy Lane',
#  'The Canyons',
#  'Kicks',
#  'Firefox',
#  'Chill Factor',
#  'The Thief and the Cobbler',
#  'Olympus Has Fallen',
#  'Monsters',
#  'Tomorrow Never Dies',
#  'The Midnight Meat Train',
#  'The Ghost and the Darkness',
#  'Medicine Man',
#  'The Ballad of Cable Hogue',
#  'Wicked Blood',
#  'The Sticky Fingers of Time',
#  'Serenity',
#  'Eagle Eye',
#  'On the Road',
#  'Action Jackson',
#  'Eden',
#  'Creative Control',
#  'Red Sky',
#  'This Thing of Ours',
#  'The Legend of Hercules',
#  'The Deep End of the Ocean',
#  'The Mechanic',
#  'The Matrix',
#  'Easy Money',
#  'Max Keebles Big Move',
#  'Midnight in the Garden of Good and Evil',
#  'Shade',
#  '3 Days to Kill',
#  'Big Fish',
#  'Into the Grizzly Maze',
#  'The Constant Gardener',
#  'Night Watch',
#  'The Running Man',
#  'The Hunger Games',
#  'Mutant World',
#  'The Protector',
#  'Unfaithful',
#  'Alone in the Dark',
#  'Extreme Measures',
#  'The Haunted Mansion',
#  'The Thing',
#  'Home Alone 2: Lost in New York',
#  'My Super Ex-Girlfriend',
#  '1408',
#  'Jack Brooks: Monster Slayer',
#  'After the Sunset',
#  'Fantastic Mr. Fox',
#  'Inside Man',
#  'Paper Towns',
#  'Running Scared',
#  'Men in Black 3',
#  'The Witch',
#  'War of the Worlds',
#  'Impostor',
#  'Crazy Stone',
#  'Bound by Honor',
#  'Live Free or Die Hard',
#  'My Soul to Take',
#  'Star Trek: Nemesis',
#  'The Prestige',
#  'Sleep Tight',
#  'Pootie Tang',
#  'Fight Valley',
#  'The Life Before Her Eyes',
#  'Fur: An Imaginary Portrait of Diane Arbus',
#  'I Am Wrath',
#  'Mortal Kombat: Annihilation',
#  'Pandoras Box',
#  'Another Earth',
#  'The Invasion',
#  'The House of the Devil',
#  'Pain & Gain',
#  'Megiddo: The Omega Code 2',
#  'A Dangerous Method',
#  'Midnight Special',
#  'The Last Godfather',
#  'Recess: Schools Out',
#  'Cloverfield',
#  'Takers',
#  'Bandidas',
#  'The Life Aquatic with Steve Zissou',
#  'Thomas and the Magic Railroad',
#  'Ghost Rider',
#  'The Bourne Identity',
#  'Halloween 4: The Return of Michael Myers',
#  'Hud',
#  'The Good, The Bad, The Weird',
#  'The Specialist',
#  'Crossroads',
#  'Crimson Tide',
#  '2012',
#  'Rambo: First Blood Part II',
#  'Batman & Robin',
#  'Back to the Future Part III',
#  'Firestorm',
#  'Cirque du Freak: The Vampires Assistant',
#  'Sex Drive',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  'Beverly Hills Cop II',
#  'Baby Geniuses',
#  'Bubba Ho-tep',
#  'Year One',
#  'Next Day Air',
#  'Fifty Dead Men Walking',
#  'Commando',
#  'Swimfan',
#  'Life of Pi',
#  'The Train',
#  'Wrong Turn',
#  'On Her Majestys Secret Service',
#  'All Good Things',
#  'Out of the Dark',
#  'Paranormal Activity 2',
#  'Kingdom of Heaven',
#  'Transformers',
#  'Knockaround Guys',
#  'The Curse of Downers Grove',
#  'Shutter Island',
#  'Cliffhanger',
#  'The Book of Eli',
#  'Return to the Blue Lagoon',
#  'Eyes Wide Shut',
#  'Wild Things',
#  'Chain Reaction',
#  'Minority Report',
#  'The Curious Case of Benjamin Button',
#  'Interstellar',
#  'Saving Private Perez',
#  'Mission to Mars',
#  'Darling Lili',
#  'Harry Potter and the Philosophers Stone',
#  'Menace II Society',
#  'The Untouchables',
#  'Spider-Man',
#  'Renaissance',
#  'The Hunting Party',
#  'Made',
#  'Hard to Be a God',
#  'Shaolin Soccer',
#  'The Manchurian Candidate',
#  'Casino Royale',
#  'The Godfather: Part III',
#  'VeggieTales: The Pirates Who Dont Do Anything',
#  'Dum Maaro Dum',
#  'Pocahontas',
#  'Big Trouble in Little China',
#  'TRON: Legacy',
#  'Virgin Territory',
#  'The Visit',
#  'Terminator Genisys',
#  'Mortal Kombat',
#  'Train',
#  'Only God Forgives',
#  'The Three Burials of Melquiades Estrada',
#  'Highlander: Endgame',
#  'Special',
#  'Big Miracle',
#  'Muppets Most Wanted',
#  'Ninja Assassin',
#  'The Tailor of Panama',
#  'Enter the Dangerous Mind',
#  'Reign of Assassins',
#  'Tales from the Hood',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Nurse 3-D',
#  'Ghost Ship',
#  'Yesterday Was a Lie',
#  'Beyond the Black Rainbow',
#  'Captive',
#  'A Lonely Place to Die',
#  'Drive Hard',
#  'Abandon',
#  'The Bourne Legacy',
#  'Twilight Zone: The Movie',
#  'Resident Evil: Retribution',
#  'Survivor',
#  'The Clan of the Cave Bear',
#  'The Legend of Gods Gun',
#  'Shaft',
#  'G-Force',
#  'Pride and Glory',
#  'Black Swan',
#  'The Lady from Shanghai',
#  'The Blue Butterfly',
#  'The Devils Own',
#  'Superman',
#  'No Escape',
#  'Foodfight!',
#  'Pulse',
#  'Albino Alligator',
#  'Tycoon',
#  'The Golden Compass',
#  'Kiss of the Dragon',
#  'Space Cowboys',
#  'Tombstone',
#  'Shrek the Third',
#  'Underworld',
#  'Iron Man',
#  'Showdown in Little Tokyo',
#  'Brooklyn Rules',
#  'Sherlock Holmes',
#  'The Last Shot',
#  'Set It Off',
#  'Mad City',
#  'Rush',
#  'Bad Boys',
#  'Vanilla Sky',
#  'Bait',
#  'The Smurfs',
#  'Harley Davidson and the Marlboro Man',
#  'High Tension',
#  'Match Point',
#  'War',
#  'A Most Violent Year',
#  'Team America: World Police',
#  'Cavite',
#  'Kick-Ass 2',
#  'Highlander: The Final Dimension',
#  'Indiana Jones and the Last Crusade',
#  'I Am Number Four',
#  'The Princess Bride',
#  'Maria Full of Grace',
#  'I Spit on Your Grave',
#  'The Negotiator',
#  'Street Fighter',
#  'The Blair Witch Project',
#  'Benji',
#  'Attack the Block',
#  'Warlock',
#  'Nine Dead',
#  'Windtalkers',
#  'The Oxford Murders',
#  'The Business of Strangers',
#  'Jason Bourne',
#  'Catch a Fire',
#  '1911',
#  'Tinker Tailor Soldier Spy',
#  'Letters to God',
#  'Shark Tale',
#  'Skin Trade',
#  'The Jungle Book 2',
#  'Galaxina',
#  'Atlantis: The Lost Empire',
#  'Left Behind',
#  'Anatomy',
#  'Delgo',
#  'Teenage Mutant Ninja Turtles III',
#  'The Quiet American',
#  'Keanu',
#  'Raiders of the Lost Ark',
#  'All the Kings Men',
#  'Birthday Girl',
#  'Silverado',
#  'The Words',
#  'National Lampoons Vacation',
#  'The Longest Day',
#  'The Nutty Professor',
#  'Paul Blart: Mall Cop 2',
#  'Thinner',
#  'Gone Girl',
#  'Guardians of the Galaxy',
#  'Confidence',
#  'Catwoman',
#  'Ant-Man',
#  'Seven Years in Tibet',
#  'Men in Black II',
#  'The Lost World: Jurassic Park',
#  'Immortals',
#  'Code Name: The Cleaner',
#  'Mission: Impossible - Ghost Protocol',
#  'The Possession',
#  'Funny Games',
#  'Eye for an Eye',
#  'The Wild Bunch',
#  '20,000 Leagues Under the Sea',
#  'The Hebrew Hammer',
#  'Cradle 2 the Grave',
#  'The Boondock Saints',
#  'True Lies',
#  'Bound',
#  'The Brass Teapot',
#  'Hot Pursuit',
#  'Antarctica: A Year on Ice',
#  'Dungeons & Dragons: Wrath of the Dragon God',
#  'Salton Sea',
#  'The Night Listener',
#  'Alexander',
#  'The Revenant',
#  'Central Intelligence',
#  '88 Minutes',
#  'Some Guy Who Kills People',
#  'Priest',
#  'Butterfly on a Wheel',
#  'Nomad: The Warrior',
#  'Sympathy for Lady Vengeance',
#  'The Day After Tomorrow',
#  'Unfriended',
#  'Galaxy Quest',
#  'Space Pirate Captain Harlock',
#  'S.W.A.T.',
#  'Twixt',
#  '[REC]',
#  'Reindeer Games',
#  'The Incredibles',
#  'Big Hero 6',
#  'Behind Enemy Lines',
#  'Braveheart',
#  'Poltergeist III',
#  'Maximum Risk',
#  'Bodyguards and Assassins',
#  'The Fourth Kind',
#  'Into the Wild',
#  'Transformers: Age of Extinction',
#  'Amidst the Devils Wings',
#  'Harold & Kumar Escape from Guantanamo Bay',
#  'The X Files: I Want to Believe',
#  'Sands of Iwo Jima',
#  'The Girl with the Dragon Tattoo',
#  'The Sum of All Fears',
#  'Gossip',
#  'Detention',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Plastic',
#  'The Borrowers',
#  'Lake Placid',
#  'Speed',
#  'Subway',
#  'Rumble in the Bronx',
#  'Raising Cain',
#  'Crank: High Voltage',
#  'Open Road',
#  'Blades of Glory',
#  'Hitman',
#  'Mr. & Mrs. Smith',
#  'Snow White: A Deadly Summer',
#  'John Q',
#  'Confessions of a Dangerous Mind',
#  'Tower Heist',
#  'Changing Lanes',
#  'The Avengers',
#  'Boom Town',
#  'Dune',
#  'The Last Exorcism',
#  'The Call',
#  'Triple 9',
#  'What Planet Are You From?',
#  'Pineapple Express',
#  'The Number 23',
#  'The Forest',
#  'Spellbound',
#  'Pirates of the Caribbean: At Worlds End',
#  'Harper',
#  'The Infiltrator',
#  'The Firm',
#  'Friday the 13th Part 2',
#  'H.',
#  'Disturbia',
#  'Arbitrage',
#  'The Village',
#  'Superman Returns',
#  'Journey to the Center of the Earth',
#  'Oz: The Great and Powerful',
#  'Dogma',
#  'Dinner Rush',
#  'Straightheads',
#  'The Counselor',
#  'The Purge',
#  'Antitrust',
#  'Cry_Wolf',
#  'Atlas Shrugged Part III: Who is John Galt?',
#  'Kiss Kiss Bang Bang',
#  'The Iceman',
#  'Snowpiercer',
#  'Sleepers',
#  'U-571',
#  'Body of Lies',
#  'Paint Your Wagon',
#  'Rio',
#  'Jumper',
#  'The Wash',
#  'The Killer Inside Me',
#  'Faster',
#  'Zambezia',
#  'The Crow',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'Mystic River',
#  'F.I.S.T.',
#  'Hard Rain',
#  'Open Secret',
#  'Down Terrace',
#  'Brighton Rock',
#  'Slow West',
#  'The Wild Thornberrys Movie',
#  'Gerry',
#  'Rush Hour 3',
#  'Mission: Impossible III',
#  'Halloween 5: The Revenge of Michael Myers',
#  'Everest',
#  'Star Trek',
#  'The Road',
#  'Trust',
#  'The Conversation',
#  'The Fast and the Furious',
#  'Carousel of Revenge',
#  'Basic Instinct 2',
#  'Oceans Thirteen',
#  'The Cabin in the Woods',
#  'The Green Inferno',
#  'The Greatest Show on Earth',
#  'Turbulence',
#  'Amistad',
#  'Queen Crab',
#  'Niagara',
#  'Bloody Sunday',
#  'Blood Diamond',
#  'Killers',
#  'Original Sin',
#  'The Muppet Movie',
#  'The Covenant',
#  'The Empire Strikes Back',
#  'Jack the Giant Slayer',
#  'Edge of Darkness',
#  'Jeepers Creepers',
#  'Alien: Resurrection',
#  'Race',
#  'The Game',
#  'Stir of Echoes',
#  'Clash of the Titans',
#  'Higher Ground',
#  'Narc',
#  'Michael Clayton',
#  'Mission: Impossible II',
#  'Batman: The Dark Knight Returns, Part 2',
#  'Birth',
#  'Without a Paddle',
#  'We Were Soldiers',
#  'What Lies Beneath',
#  'Joe Dirt',
#  'Airlift',
#  'Tropic Thunder',
#  'Austin Powers: The Spy Who Shagged Me',
#  'Gravity',
#  'Transsiberian',
#  'Akira',
#  '2 Guns',
#  'Maze Runner: The Scorch Trials',
#  '10th & Wolf',
#  'Shrek Forever After',
#  'Crossover',
#  'The French Connection',
#  'The Art of War',
#  'Moby Dick',
#  'Regression',
#  'Inescapable',
#  'The Transporter Refueled',
#  'A Nightmare on Elm Street 3: Dream Warriors',
#  'In the Bedroom',
#  'Blade',
#  'Summer of Sam',
#  'Heroes of Dirt',
#  'Code of Honor',
#  'The Craft',
#  'Sphinx',
#  'Bulletproof Monk',
#  'The Dead Zone',
#  'Jimmy and Judy',
#  'Gladiator',
#  'Halloween: The Curse of Michael Myers',
#  '21 Jump Street',
#  'Harry Potter and the Half-Blood Prince',
#  'The Amityville Horror',
#  'The Pirates! In an Adventure with Scientists!',
#  'A Nightmare on Elm Street 4: The Dream Master',
#  'Happily NEver After',
#  'El Mariachi',
#  'The Sixth Sense',
#  'My Favorite Martian',
#  'The International',
#  'Signs',
#  'Tank Girl',
#  'Warrior',
#  'Stake Land',
#  'The Ant Bully',
#  'Wing Commander',
#  'United 93',
#  'Silent Hill',
#  'Monty Python and the Holy Grail',
#  'Tango & Cash',
#  'Victor Frankenstein',
#  'Out of Time',
#  'JFK',
#  'Tomorrowland',
#  '300',
#  'ParaNorman',
#  'Underworld: Awakening',
#  'Star Wars: Episode III - Revenge of the Sith',
#  'Mr. Peabody & Sherman',
#  'The Spirit',
#  'The Hunt for Red October',
#  'Trade',
#  'The Rite',
#  'Super',
#  'Flipper',
#  'Donkey Punch',
#  'The Lawnmower Man',
#  'Run All Night',
#  'Shipwrecked',
#  'Whiteout',
#  'Broken City',
#  'Syriana',
#  'Slow Burn',
#  'The Corruptor',
#  'The Spy Who Loved Me',
#  'The Incredible Hulk',
#  'All The Queens Men',
#  'Ace Ventura: When Nature Calls',
#  'The Crying Game',
#  'Godsend',
#  'The Wicked Lady',
#  'Brigham City',
#  'Blackhat',
#  'Mercy Streets',
#  'The Nut Job',
#  'Top Gun',
#  'Oblivion',
#  'Master and Commander: The Far Side of the World',
#  'Compliance',
#  'The Toxic Avenger Part II',
#  'Double Jeopardy',
#  'Oldboy',
#  'Scream 2',
#  'Stolen',
#  'The Nutcracker: The Untold Story',
#  'In Time',
#  'Assassins',
#  'Savages',
#  'The Replacement Killers',
#  'Krrish',
#  'Terminator 3: Rise of the Machines',
#  'May',
#  'The Devils Advocate',
#  'Dream House',
#  'Subconscious',
#  'The Boondock Saints II: All Saints Day',
#  'Black November',
#  'The Pet',
#  'Gangster Squad',
#  'American Psycho',
#  'Tidal Wave',
#  'Drive Angry',
#  'The Last Samurai',
#  'Taken 3',
#  'Colombiana',
#  'One for the Money',
#  'The Ghost Writer',
#  'Young Frankenstein',
#  'The Best Offer',
#  'All Hat',
#  'Volcano',
#  'Eternal Sunshine of the Spotless Mind',
#  'The Man from Snowy River',
#  'Legend of a Rabbit',
#  'Silent Trigger',
#  'Straw Dogs',
#  'Cube',
#  'Snow Dogs',
#  'The Andromeda Strain',
#  'Bangkok Dangerous',
#  'Snitch',
#  'In the Cut',
#  'Nighthawks',
#  'The Matrix Revolutions',
#  'Close Range',
#  'Indiana Jones and the Temple of Doom',
#  'Child 44',
#  'Source Code',
#  'Trash',
#  'My Stepmother is an Alien',
#  'The Client',
#  'Assault on Precinct 13',
#  'Salt',
#  'Jack Reacher',
#  'Topaz',
#  'Compadres',
#  'End of the Spear',
#  'Young Guns',
#  'Taken',
#  'Monkeybone',
#  'Hav Plenty',
#  'Checkmate',
#  'The Lord of the Rings: The Two Towers',
#  'The Land Before Time',
#  'From Hell',
#  'Oceans Eleven',
#  'Hidalgo',
#  'Centurion',
#  'Sky Captain and the World of Tomorrow',
#  'Witness',
#  'The Perfect Host',
#  'London Has Fallen',
#  'The Hobbit: The Desolation of Smaug',
#  'Armored',
#  'Midnight Run',
#  'As Above, So Below',
#  'Feast',
#  'Killer Joe',
#  'Batman Returns',
#  'The Skeleton Key',
#  'Super 8',
#  'Pound of Flesh',
#  'N-Secure',
#  'White House Down',
#  'Stormbreaker',
#  'The Devil Inside',
#  'MacGruber',
#  'The Quick and the Dead',
#  'Plush',
#  'Misconduct',
#  'The Rage: Carrie 2',
#  'Small Soldiers',
#  'Khiladi 786',
#  'RockNRolla',
#  'A Scanner Darkly',
#  'The Twilight Saga: Breaking Dawn - Part 2',
#  'The Black Stallion',
#  'The Amazing Spider-Man 2',
#  'The Man with the Golden Gun',
#  'The Newton Boys',
#  'Dark Water',
#  'RoboCop 3',
#  'Virtuosity',
#  'Goddess of Love',
#  'Project Almanac',
#  'The Lord of the Rings: The Return of the King',
#  'The Marine',
#  'The Imaginarium of Doctor Parnassus',
#  'Gone in Sixty Seconds',
#  'Penguins of Madagascar',
#  'Astro Boy',
#  'See Spot Run',
#  'Texas Rangers',
#  'Back to the Future',
#  'Deadfall',
#  'The Ninth Gate',
#  'The Innkeepers',
#  'Torque',
#  'Mulan',
#  'Into the Storm',
#  'Dark Blue',
#  'Devil',
#  'Mary Reilly',
#  'Rosemarys Baby',
#  'The Interview',
#  'Grand Theft Parsons',
#  'Spice World',
#  'The Boy Next Door',
#  'Harry Potter and the Chamber of Secrets',
#  'The Stepfather',
#  'Captain Phillips',
#  'Where the Truth Lies',
#  'Red Sonja',
#  '13 Hours: The Secret Soldiers of Benghazi',
#  'The Hunted',
#  'The BFG',
#  'House at the End of the Drive',
#  'Case 39',
#  'The Mighty Macs',
#  'Predator 2',
#  'Escape from L.A.',
#  'Fury',
#  '3000 Miles to Graceland',
#  'Minions',
#  'The True Story of Puss n Boots',
#  'I, Frankenstein',
#  'Children of Men',
#  'Jaws: The Revenge',
#  'The Last of the Mohicans',
#  'Pirates of the Caribbean: Dead Mans Chest',
#  'Money Train',
#  'Kangaroo Jack',
#  'Exit Wounds',
#  'Smokin Aces',
#  'Romeo Must Die',
#  'The Man Who Knew Too Little',
#  'The Mummy Returns',
#  'Love Letters',
#  'Dawn of the Dead',
#  'The Dark Knight',
#  'Rendition',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Silent Running',
#  'Knock Off',
#  'Swimming Pool',
#  'Seventh Son',
#  'Spy Kids 3-D: Game Over',
#  'The Bounty',
#  'Chernobyl Diaries',
#  'TMNT',
#  'Dylan Dog: Dead of Night',
#  'Lies in Plain Sight',
#  'Batman Begins',
#  'Cecil B. Demented',
#  'Very Bad Things',
#  'Invasion U.S.A.',
#  'Night at the Museum: Battle of the Smithsonian',
#  'Fortress',
#  'Stargate: The Ark of Truth',
#  'Get Low',
#  'Hellboy II: The Golden Army',
#  'The Lone Ranger',
#  'One Hour Photo',
#  ...]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {0: 2, 1: 1.3, 2:1, 3:0.7, 4:0.3} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = simple_recommender(movie)
        simillist = list(similar_movies)

        for similar_movie in similar_movies:
          if simillist.index(similar_movie) < len(simillist)/25: f= 1
          elif simillist.index(similar_movie) <len(simillist)/10 : f = 2
          else: f = 3
          if similar_movie not in movie_score:
              movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[f]
          else:
              movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[f] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred, zero_division = 0)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %% [markdown]
# ```
# #Επειδη κρασαρει, την μια φορα που ετρεξε εβγαλε τα παρακατω αποτελεσματα:
#
# 10/? [00:09<00:00, 1.05s/it]
# 10/? [00:06<00:00, 2.39it/s]
# 10/? [00:03<00:00, 2.73it/s]
# 10/? [00:05<00:00, 2.83it/s]
# 10/? [00:02<00:00, 4.95it/s]
# 10/? [00:02<00:00, 3.49it/s]
# 10/? [00:02<00:00, 3.72it/s]
# 10/? [00:04<00:00, 2.10it/s]
# 10/? [00:02<00:00, 3.51it/s]
# 10/? [00:02<00:00, 4.41it/s]
# precision: 0.4993342202544541
# recall: 0.5638888888888889
# f1: 0.4747169563252072
# ```

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 20)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")

# %% [markdown]
# ```
# #Επειδη κρασαρει, την μια φορα που ετρεξε εβγαλε τα παρακατω αποτελεσματα:
#
# 20/? [00:05<00:00, 3.59it/s]
# 20/? [00:07<00:00, 2.93it/s]
# 20/? [00:05<00:00, 4.19it/s]
# 20/? [00:06<00:00, 4.36it/s]
# 20/? [00:07<00:00, 1.12s/it]
# 20/? [00:07<00:00, 2.84it/s]
# 20/? [00:04<00:00, 4.51it/s]
# 20/? [00:06<00:00, 3.93it/s]
# 20/? [00:06<00:00, 3.79it/s]
# 20/? [00:07<00:00, 2.03it/s]
# precision: 0.5114508393897398
# recall: 0.7944444444444445
# f1: 0.6072453558027593
# ```
